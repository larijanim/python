# %% [markdown]
# <a href="https://colab.research.google.com/github/larijanim/python/blob/main/week4_maryam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
str1="test of string"
x=str1.replace('test','head')

from google.colab import files
uploaded=files.upload()
df=pd.read_csv('/content/df.csv')
# Out:
#      <input type="file" id="files-7252aa58-c2be-4a63-adfe-2bddaf1eb0ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7252aa58-c2be-4a63-adfe-2bddaf1eb0ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def sq(num):
  s=num * num
  return s

sq(5)
# Out:
# 25

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df['Salary Estimate'][0].replace('$',' ')
# Out:
# ' 111K- 181K (Glassdoor est.)'

# %%
def dollar_remover(a):
  a=a.replace('$',' ')
  return a

df['Salary Estimate']=df['Salary Estimate'].apply(dollar_remover)

# %%
def k_remover(a):
  a=a.replace('k',' ')
  return a

df['Salary Estimate']=df['Salary Estimate'].apply(k_remover)

# %%
df =df[~df['Salary Estimate'].str.contains('Per Hour')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5866 entries, 0 to 5890
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5866 non-null   object
#  1   Salary Estimate    5866 non-null   object
#  2   Rating             5866 non-null   float64
#  3   Company Name       5866 non-null   object
#  4   Location           5866 non-null   object
#  5   Size               5866 non-null   object
#  6   Founded            5866 non-null   object
#  7   Type of ownership  5866 non-null   object
#  8   Industry           5866 non-null   object
#  9   Sector             5866 non-null   object
#  10  Revenue            5866 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 549.9+ KB

# %%
df['Salary Estimate'][0].split()
# Out:
# ['111K-', '181K', '(Glassdoor', 'est.)']

# %%
df['Salary Estimate'][0].split()[2]
# Out:
# '(Glassdoor'
